# %%
import pandas as pd
import numpy as np

# Read data
df_train = pd.read_csv('train.csv')
df_holidays = pd.read_csv('holidays_events.csv')
#df_train.head(10)
#df_holidays.head(10)

# %%
# 日期格式轉換
df_train['date'] = pd.to_datetime(df_train['date']) 
df_holidays['date'] = pd.to_datetime(df_holidays['date'])
#df_train.head(10)
df_holidays.head(10)
# Out:
#         date     type    locale locale_name                    description  \
# 0 2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1 2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2 2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3 2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4 2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
# 5 2012-05-12  Holiday     Local        Puyo         Cantonizacion del Puyo
# 6 2012-06-23  Holiday     Local    Guaranda      Cantonizacion de Guaranda
# 7 2012-06-25  Holiday  Regional    Imbabura  Provincializacion de Imbabura
# 8 2012-06-25  Holiday     Local   Latacunga     Cantonizacion de Latacunga
# 9 2012-06-25  Holiday     Local     Machala           Fundacion de Machala
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False

# %%
# 檢查是否有NA值
df_holidays.isna().sum()
# Out:
# date           0
# type           0
# locale         0
# locale_name    0
# description    0
# transferred    0
# dtype: int64

# %%
# merge df_holidays to df_train
# convert date column to datetime64[ns]
df_train = df_train.merge(df_holidays, how='left', on='date')
display(df_train.head(10))
# Out:
#    id       date  store_nbr        family  sales  onpromotion     type  \
# 0   0 2013-01-01          1    AUTOMOTIVE    0.0            0  Holiday
# 1   1 2013-01-01          1     BABY CARE    0.0            0  Holiday
# 2   2 2013-01-01          1        BEAUTY    0.0            0  Holiday
# 3   3 2013-01-01          1     BEVERAGES    0.0            0  Holiday
# 4   4 2013-01-01          1         BOOKS    0.0            0  Holiday
# 5   5 2013-01-01          1  BREAD/BAKERY    0.0            0  Holiday
# 6   6 2013-01-01          1   CELEBRATION    0.0            0  Holiday
# 7   7 2013-01-01          1      CLEANING    0.0            0  Holiday
# 8   8 2013-01-01          1         DAIRY    0.0            0  Holiday
# 9   9 2013-01-01          1          DELI    0.0            0  Holiday
#
#      locale locale_name         description transferred
# 0  National     Ecuador  Primer dia del ano       False
# 1  National     Ecuador  Primer dia del ano       False
# 2  National     Ecuador  Primer dia del ano       False
# 3  National     Ecuador  Primer dia del ano       False
# 4  National     Ecuador  Primer dia del ano       False
# 5  National     Ecuador  Primer dia del ano       False
# 6  National     Ecuador  Primer dia del ano       False
# 7  National     Ecuador  Primer dia del ano       False
# 8  National     Ecuador  Primer dia del ano       False
# 9  National     Ecuador  Primer dia del ano       False

# %%
# encode 
df_train = pd.get_dummies(df_train, columns=['family'], dummy_na=False, prefix='family')
df_train = pd.get_dummies(df_train, columns=['type'], dummy_na=False, prefix='Holiday_Type_Is')
df_train = pd.get_dummies(df_train, columns=['locale'], dummy_na=False, prefix='Holiday_Is_local')
df_train = pd.get_dummies(df_train, columns=['transferred'], dummy_na=False, prefix='Holiday_Is_transferred')

# %%
# remove duplicates
df_train[df_train['id'].duplicated(keep='first')]
df_train[df_train['id'].duplicated(keep=False)]
# Out:
#               id       date  store_nbr     sales  onpromotion    locale_name  \
# 233442    233442 2013-05-12          1     1.000            0           Puyo
# 233443    233442 2013-05-12          1     1.000            0        Ecuador
# 233444    233443 2013-05-12          1     0.000            0           Puyo
# 233445    233443 2013-05-12          1     0.000            0        Ecuador
# 233446    233444 2013-05-12          1     0.000            0           Puyo
# ...          ...        ...        ...       ...          ...            ...
# 2977717  2924259 2017-07-03          9  1797.212            9  Santo Domingo
# 2977718  2924260 2017-07-03          9     2.000            0      El Carmen
# 2977719  2924260 2017-07-03          9     2.000            0  Santo Domingo
# 2977720  2924261 2017-07-03          9    17.335            0      El Carmen
# 2977721  2924261 2017-07-03          9    17.335            0  Santo Domingo
#
#                         description  family_AUTOMOTIVE  family_BABY CARE  \
# 233442       Cantonizacion del Puyo               True             False
# 233443              Dia de la Madre               True             False
# 233444       Cantonizacion del Puyo              False              True
# 233445              Dia de la Madre              False              True
# 233446       Cantonizacion del Puyo              False             False
# ...                             ...                ...               ...
# 2977717  Fundacion de Santo Domingo              False             False
# 2977718  Cantonizacion de El Carmen              False             False
# 2977719  Fundacion de Santo Domingo              False             False
# 2977720  Cantonizacion de El Carmen              False             False
# 2977721  Fundacion de Santo Domingo              False             False
#
#          family_BEAUTY  ...  Holiday_Type_Is_Bridge  Holiday_Type_Is_Event  \
# 233442           False  ...                   False                  False
# 233443           False  ...                   False                   True
# 233444           False  ...                   False                  False
# 233445           False  ...                   False                   True
# 233446            True  ...                   False                  False
# ...                ...  ...                     ...                    ...
# 2977717          False  ...                   False                  False
# 2977718          False  ...                   False                  False
# 2977719          False  ...                   False                  False
# 2977720          False  ...                   False                  False
# 2977721          False  ...                   False                  False
#
#          Holiday_Type_Is_Holiday  Holiday_Type_Is_Transfer  \
# 233442                      True                     False
# 233443                     False                     False
# 233444                      True                     False
# 233445                     False                     False
# 233446                      True                     False
# ...                          ...                       ...
# 2977717                     True                     False
# 2977718                     True                     False
# 2977719                     True                     False
# 2977720                     True                     False
# 2977721                     True                     False
#
#          Holiday_Type_Is_Work Day  Holiday_Is_local_Local  \
# 233442                      False                    True
# 233443                      False                   False
# 233444                      False                    True
# 233445                      False                   False
# 233446                      False                    True
# ...                           ...                     ...
# 2977717                     False                    True
# 2977718                     False                    True
# 2977719                     False                    True
# 2977720                     False                    True
# 2977721                     False                    True
#
#          Holiday_Is_local_National  Holiday_Is_local_Regional  \
# 233442                       False                      False
# 233443                        True                      False
# 233444                       False                      False
# 233445                        True                      False
# 233446                       False                      False
# ...                            ...                        ...
# 2977717                      False                      False
# 2977718                      False                      False
# 2977719                      False                      False
# 2977720                      False                      False
# 2977721                      False                      False
#
#          Holiday_Is_transferred_False  Holiday_Is_transferred_True
# 233442                           True                        False
# 233443                           True                        False
# 233444                           True                        False
# 233445                           True                        False
# 233446                           True                        False
# ...                               ...                          ...
# 2977717                          True                        False
# 2977718                          True                        False
# 2977719                          True                        False
# 2977720                          True                        False
# 2977721                          True                        False
#
# [96228 rows x 51 columns]

# %%
print(f'After removing duplicates {df.shape}')
